# %%
import pandas as pd
import pingouin
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\felip\OneDrive\Python, SQL & CyberSec\DataCamp-Github\Hypothesis Testing in Python.ipynb Cell 1 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/felip/OneDrive/Python%2C%20SQL%20%26%20CyberSec/DataCamp-Github/Hypothesis%20Testing%20in%20Python.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/felip/OneDrive/Python%2C%20SQL%20%26%20CyberSec/DataCamp-Github/Hypothesis%20Testing%20in%20Python.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import pingouin
#
# ModuleNotFoundError: No module named 'pingouin'

# %%
pip install pingouin
# Out:
# ...
#   Using cached pingouin-0.5.3-py3-none-any.whl (198 kB)
# ...
#      --------------------------------------- 42.2/42.2 MB 12.1 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for pandas-flavor>=0.2.0 from https://files.pythonhosted.org/packages/67/1a/bfb5574b215f530c7ac5be684f33d60b299abbebd763c203aa31755f2fb2/pandas_flavor-0.6.0-py3-none-any.whl.metadata
# ...
#      ------------------------------------- 973.1/973.1 kB 15.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Obtaining dependency information for numpy>=1.19 from https://files.pythonhosted.org/packages/69/65/0d47953afa0ad569d12de5f65d964321c208492064c38fe3b0b9744f8d44/numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 14.9/14.9 MB 13.1 MB/s eta 0:00:00
# ...

# %%
late_shipments = pd.read_feather('Datasets/late_shipments.feather')
late_shipments.head()
# Out:
#         id       country managed_by  fulfill_via vendor_inco_term  \
# 0  36203.0       Nigeria   PMO - US  Direct Drop              EXW
# 1  30998.0      Botswana   PMO - US  Direct Drop              EXW
# 2  69871.0       Vietnam   PMO - US  Direct Drop              EXW
# 3  17648.0  South Africa   PMO - US  Direct Drop              DDP
# 4   5647.0        Uganda   PMO - US  Direct Drop              EXW
#
#   shipment_mode  late_delivery late product_group    sub_classification  ...  \
# 0           Air            1.0  Yes          HRDT              HIV test  ...
# 1           Air            0.0   No          HRDT              HIV test  ...
# 2           Air            0.0   No           ARV                 Adult  ...
# 3         Ocean            0.0   No           ARV                 Adult  ...
# 4           Air            0.0   No          HRDT  HIV test - Ancillary  ...
#
#   line_item_quantity line_item_value pack_price unit_price  \
# ...
